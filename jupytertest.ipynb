# %%
from sqlalchemy.engine import create_engine



from sqlalchemy import create_engine, text
from sqlalchemy.sql import text
import mysql.connector

db = {
        'user' : 'root',
        'password' : 'DLwjdghks139@',
        'host' : 'localhost',
        'port' : 3306,
        'database' : 'miniter'
}

# %%
DB_URL = f"mysql+mysqlconnector://{db['user']}:{db['password']}@{db['host']}:{db['port']}/{db['database']}?charset=utf8"
db = create_engine(DB_URL, encoding = 'utf-8', max_overflow = 0)

# %%
sql = """insert into users(name,email,profile,hashed_password) values (%s, %s, %s, %s)"""

# %%
db.execute(sql,(
                'junghwan',
                '123@gmail.com',
                'hola',
                'teset12'
        )   
)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~/anaconda3/envs/api/lib/python3.7/site-packages/mysql/connector/connection_cext.py in _open_connection(self)
#     235         try:
# --> 236             self._cmysql.connect(**cnx_kwargs)
#     237             self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Unknown MySQL server host '@localhost' (-2)
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3249         try:
# -> 3250             return fn()
#    3251         except dialect.dbapi.Error as e:
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/pool/base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     255
# --> 256         return _ConnectionRecord(self)
#     257
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     370         if connect:
# --> 371             self.__connect()
#     372         self.finalize_callback = deque()
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     665             with util.safe_reraise():
# --> 666                 pool.logger.debug("Error on connect(): %s", e)
#     667         else:
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     660             self.starttime = time.time()
# --> 661             self.dbapi_connection = connection = pool._invoke_creator(self)
#     662             pool.logger.debug("Created new connection %r", connection)
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     589                         return connection
# --> 590             return dialect.connect(*cargs, **cparams)
#     591
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     596         # inherits the docstring from interfaces.Dialect.connect
# --> 597         return self.dbapi.connect(*cargs, **cparams)
#     598
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/mysql/connector/__init__.py in connect(*args, **kwargs)
#     271     if HAVE_CEXT and not use_pure:
# --> 272         return CMySQLConnection(*args, **kwargs)
#     273     return MySQLConnection(*args, **kwargs)
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/mysql/connector/connection_cext.py in __init__(self, **kwargs)
#      84         if kwargs:
# ---> 85             self.connect(**kwargs)
#      86
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/mysql/connector/abstracts.py in connect(self, **kwargs)
#    1013         self.disconnect()
# -> 1014         self._open_connection()
#    1015         # Server does not allow to run any other statement different from ALTER
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/mysql/connector/connection_cext.py in _open_connection(self)
#     241             raise errors.get_mysql_exception(msg=exc.msg, errno=exc.errno,
# --> 242                                              sqlstate=exc.sqlstate)
#     243
#
# DatabaseError: 2005 (HY000): Unknown MySQL server host '@localhost' (-2)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipykernel_4295/27304022.py in <module>
#       1 db.execute(sql,(
# ----> 2                 'junghwan',
#       3                 '123@gmail.com',
#       4                 'hola',
#       5                 'teset12'
#
# <string> in execute(self, statement, *multiparams, **params)
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     399         if not skip_warning:
#     400             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 401         return fn(*args, **kwargs)
#     402
#     403     doc = func.__doc__ is not None and func.__doc__ or ""
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    3143
#    3144         """
# -> 3145         connection = self.connect(close_with_result=True)
#    3146         return connection.execute(statement, *multiparams, **params)
#    3147
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/engine/base.py in connect(self, close_with_result)
#    3202         """
#    3203
# -> 3204         return self._connection_cls(self, close_with_result=close_with_result)
#    3205
#    3206     @util.deprecated(
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    3281
#    3282         """
# -> 3283         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3284
#    3285
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3252             if connection is None:
#    3253                 Connection._handle_dbapi_exception_noconnection(
# -> 3254                     e, dialect, self
#    3255                 )
#    3256             else:
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2099         elif should_wrap:
#    2100             util.raise_(
# -> 2101                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2102             )
#    2103         else:
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3248         dialect = self.dialect
#    3249         try:
# -> 3250             return fn()
#    3251         except dialect.dbapi.Error as e:
#    3252             if connection is None:
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/pool/base.py in connect(self)
#     308
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#     312     def _return_conn(self, record):
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     866     def _checkout(cls, pool, threadconns=None, fairy=None):
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#     870             fairy._pool = pool
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     474     @classmethod
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#     478             dbapi_connection = rec.get_connection()
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     144             except:
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#     148             return self._do_get()
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      70                 compat.raise_(
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#      74         else:
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     141         if self._inc_overflow():
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#     145                 with util.safe_reraise():
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     254         """Called by subclasses to create a new ConnectionRecord."""
#     255
# --> 256         return _ConnectionRecord(self)
#     257
#     258     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     369         self.__pool = pool
#     370         if connect:
# --> 371             self.__connect()
#     372         self.finalize_callback = deque()
#     373
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     664         except Exception as e:
#     665             with util.safe_reraise():
# --> 666                 pool.logger.debug("Error on connect(): %s", e)
#     667         else:
#     668             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      70                 compat.raise_(
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#      74         else:
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     659         try:
#     660             self.starttime = time.time()
# --> 661             self.dbapi_connection = connection = pool._invoke_creator(self)
#     662             pool.logger.debug("Created new connection %r", connection)
#     663             self.fresh = True
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     588                     if connection is not None:
#     589                         return connection
# --> 590             return dialect.connect(*cargs, **cparams)
#     591
#     592         creator = pop_kwarg("creator", connect)
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     595     def connect(self, *cargs, **cparams):
#     596         # inherits the docstring from interfaces.Dialect.connect
# --> 597         return self.dbapi.connect(*cargs, **cparams)
#     598
#     599     def create_connect_args(self, url):
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/mysql/connector/__init__.py in connect(*args, **kwargs)
#     270
#     271     if HAVE_CEXT and not use_pure:
# --> 272         return CMySQLConnection(*args, **kwargs)
#     273     return MySQLConnection(*args, **kwargs)
#     274 Connect = connect  # pylint: disable=C0103
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/mysql/connector/connection_cext.py in __init__(self, **kwargs)
#      83
#      84         if kwargs:
# ---> 85             self.connect(**kwargs)
#      86
#      87     def _add_default_conn_attrs(self):
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/mysql/connector/abstracts.py in connect(self, **kwargs)
#    1012
#    1013         self.disconnect()
# -> 1014         self._open_connection()
#    1015         # Server does not allow to run any other statement different from ALTER
#    1016         # when user's password has been expired.
#
# ~/anaconda3/envs/api/lib/python3.7/site-packages/mysql/connector/connection_cext.py in _open_connection(self)
#     240         except MySQLInterfaceError as exc:
#     241             raise errors.get_mysql_exception(msg=exc.msg, errno=exc.errno,
# --> 242                                              sqlstate=exc.sqlstate)
#     243
#     244         self._do_handshake()
#
# DatabaseError: (mysql.connector.errors.DatabaseError) 2005 (HY000): Unknown MySQL server host '@localhost' (-2)
# (Background on this error at: https://sqlalche.me/e/14/4xp6)
